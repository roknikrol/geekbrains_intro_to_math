# %% [markdown]
# ### Задание 1

# %% [markdown]
# Я пытался решить на листочке уравнения параболы через матрицу, но где-то ошибся в подсчете. В итоге использовал модуль numpy.linalg

# %% [markdown]
# ![photo_2019-12-14_16-40-55.jpg](attachment:photo_2019-12-14_16-40-55.jpg)

# %%
import numpy as np
import numpy.linalg as linal

# %%
am = np.array([[1, 1, 1],
             [9, 3, 1],
             [25, 5, 1]])
bm = np.array([2, 10, 1])

# %%
det = linal.det(am)

# %%
am_inv = linal.inv(am)
am_inv
# Out:
# array([[ 0.125, -0.25 ,  0.125],
#        [-1.   ,  1.5  , -0.5  ],
#        [ 1.875, -1.25 ,  0.375]])

# %%
res = am_inv @ bm
res
# Out:
# array([-2.125, 12.5  , -8.375])

# %% [markdown]
# уравнение параболы:
# y = -2.125x^2 + 12.5x - 8.375

# %% [markdown]
# ### Задание 2

# %% [markdown]
# ответ 98,98кг. Система уравнений либо пропорция.

# %% [markdown]
# ![photo_2019-12-14_16-43-54.jpg](attachment:photo_2019-12-14_16-43-54.jpg)

# %% [markdown]
# ### Задание 3

# %%
Первое решается подбором
# Out:
#   File "<ipython-input-5-d443beaa4699>", line 1
#     Первое решается подбором
#                   ^
# SyntaxError: invalid syntax

# %% [markdown]
# ![photo_2019-12-14_16-46-23.jpg](attachment:photo_2019-12-14_16-46-23.jpg)

# %% [markdown]
# Второе без логарифмической линейки, либо бинарным поиском, либо функцией numpy:

# %%
x = np.log2(300)
x
# Out:
# 8.228818690495881

# %%
q = 2**x
# Out:
# 300.0000000000001

# %% [markdown]
# ![photo_2019-12-14_18-30-22.jpg](attachment:photo_2019-12-14_18-30-22.jpg)

# %% [markdown]
# 5* не осилил

# %% [markdown]
# ![photo_2019-12-14_18-31-35.jpg](attachment:photo_2019-12-14_18-31-35.jpg)

# %% [markdown]
# #### Задание 4

# %% [markdown]
# в примере 10 случайно записал разные осования и решил чуть другой пример, но суть понятна (12/3 = 4, log2(4)= 2)

# %% [markdown]
# ![photo_2019-12-14_18-00-17.jpg](attachment:photo_2019-12-14_18-00-17.jpg)

# %% [markdown]
# ![photo_2019-12-14_18-00-50.jpg](attachment:photo_2019-12-14_18-00-50.jpg)

# %% [markdown]
# ![photo_2019-12-14_18-01-06.jpg](attachment:photo_2019-12-14_18-01-06.jpg)
